# %%
import pandas as pd

df = pd.read_csv("/content/plant_disease_recommendations.csv")

df.head()
df.tail()
# Out:
#                                      disease_name   plant  \
# 33  Tomato___Spider_mites Two-spotted_spider_mite  Tomato
# 34                           Tomato___Target_Spot  Tomato
# 35         Tomato___Tomato_Yellow_Leaf_Curl_Virus  Tomato
# 36                   Tomato___Tomato_mosaic_virus  Tomato
# 37                               Tomato___healthy  Tomato
#
#                                 description  \
# 33     Pest infestation causing leaf damage
# 34  Fungal disease with target-like lesions
# 35  Viral disease transmitted by whiteflies
# 36           Viral disease causing mottling
# 37                     Healthy tomato plant
#
#                                symptoms                treatment  \
# 33          Yellow speckles and webbing  Apply insecticidal soap
# 34  Brown lesions with concentric rings          Apply fungicide
# 35                 Yellow curled leaves       Control whiteflies
# 36            Mosaic patterns on leaves   Remove infected plants
# ...

# %%
row = df[df["disease_name"] == predicted_disease]

treatment = row["treatment"].values[0]
prevention = row["prevention"].values[0]

print("Treatment:", treatment)
print("Prevention:", prevention)
# Out:
# Treatment: Apply fungicides like captan or mancozeb
# Prevention: Use resistant varieties and remove infected leaves
